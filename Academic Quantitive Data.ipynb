# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame (np.random.randint(0,100, size = (1000,12)), columns = list('ABCDEFGHIJKL')) 
print (df)
# Out:
#       A   B   C   D   E   F   G   H   I   J   K   L
# 0    47  24  33  74   5  17  27  47  86  55  96  89
# 1    16  86  63  10  14  22   7  56   3  14  79  54
# 2    98  52   5  20  57  56  23  14  20  78  72  99
# 3    94  68  77  97  18  71  97  83  16  32  81   9
# 4    66  86  36  77  86   5  43   3  68  45  40  37
# ..   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 995  51  33  73  47  42  46  41  36  70  40  67  83
# 996  10  23  36  54  21  16  15  72  21  95  51  48
# 997  36   6   6  74  25  35  79  42  19  19  28  38
# 998  83  71  21  36  33  85  36  85  29  80  79  22
# 999  81  44  52  38  81  55  30  49  70  37  81  21
#
# [1000 rows x 12 columns]

# %%
df = pd.read_csv('Most-Recent-Cohorts-Field-of-Study.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of           UNITID  OPEID6                          INSTNM              CONTROL  \
# 0       100654.0    1002        Alabama A & M University               Public
# 1       100654.0    1002        Alabama A & M University               Public
# 2       100654.0    1002        Alabama A & M University               Public
# 3       100654.0    1002        Alabama A & M University               Public
# 4       100654.0    1002        Alabama A & M University               Public
# ...          ...     ...                             ...                  ...
# 224844       NaN   42640  California Southern University  Private, for-profit
# 224845       NaN   42640  California Southern University  Private, for-profit
# 224846       NaN   42753            Zion Massage College  Private, for-profit
# 224847       NaN   42837  Oregon Coast Community College               Public
# 224848       NaN   42840  Gather 4 Him Christian College   Private, nonprofit
#
# ...

# %%
print(list(df))
# Out:
# ['UNITID', 'OPEID6', 'INSTNM', 'CONTROL', 'MAIN', 'CIPCODE', 'CIPDESC', 'CREDLEV', 'CREDDESC', 'IPEDSCOUNT1', 'IPEDSCOUNT2', 'DEBT_ALL_STGP_ANY_N', 'DEBT_ALL_STGP_ANY_MEAN', 'DEBT_ALL_STGP_ANY_MDN', 'DEBT_ALL_STGP_EVAL_N', 'DEBT_ALL_STGP_EVAL_MEAN', 'DEBT_ALL_STGP_EVAL_MDN', 'DEBT_ALL_PP_ANY_N', 'DEBT_ALL_PP_ANY_MEAN', 'DEBT_ALL_PP_ANY_MDN', 'DEBT_ALL_PP_EVAL_N', 'DEBT_ALL_PP_EVAL_MEAN', 'DEBT_ALL_PP_EVAL_MDN', 'DEBT_MALE_STGP_ANY_N', 'DEBT_MALE_STGP_ANY_MEAN', 'DEBT_MALE_STGP_ANY_MDN', 'DEBT_MALE_STGP_EVAL_N', 'DEBT_MALE_STGP_EVAL_MEAN', 'DEBT_MALE_STGP_EVAL_MDN', 'DEBT_MALE_PP_ANY_N', 'DEBT_MALE_PP_ANY_MEAN', 'DEBT_MALE_PP_ANY_MDN', 'DEBT_MALE_PP_EVAL_N', 'DEBT_MALE_PP_EVAL_MEAN', 'DEBT_MALE_PP_EVAL_MDN', 'DEBT_NOTMALE_STGP_ANY_N', 'DEBT_NOTMALE_STGP_ANY_MEAN', 'DEBT_NOTMALE_STGP_ANY_MDN', 'DEBT_NOTMALE_STGP_EVAL_N', 'DEBT_NOTMALE_STGP_EVAL_MEAN', 'DEBT_NOTMALE_STGP_EVAL_MDN', 'DEBT_NOTMALE_PP_ANY_N', 'DEBT_NOTMALE_PP_ANY_MEAN', 'DEBT_NOTMALE_PP_ANY_MDN', 'DEBT_NOTMALE_PP_EVAL_N', 
# ...

# %%
dfBetter=df.loc[df['EARN_NE_MDN_3YR']!='PrivacySuppressed'&&]

# %%
col = ('EARN_NE_MDN_3YR') #<-edit this value! column name as it appears in dataframe
col_name = '(Median Earnings after 3 years)' #<-edit this value! descriptive name for column
freq= dfBetter[col].astype(int).value_counts().rename_axis(col_name).reset_index(name='freq')
freq = freq.sort_values(by = col_name)
print(freq)
# Out:
#        (Median Earnings after 3 years)  freq
# 0                                    0    70
# 14885                               40     1
# 13636                              191     1
# 12611                              394     1
# 14645                              454     1
# ...                                ...   ...
# 29566                           240408     1
# 18033                           248726     1
# 10307                           249574     1
# 23163                           249730     1
# 10348                           267734     1
#
# [29996 rows x 2 columns]

# %%
freq.hist()
# Out:
# array([[<AxesSubplot:title={'center':'(Median Earnings after 3 years)'}>,
#         <AxesSubplot:title={'center':'freq'}>]], dtype=object)

# %%
dfBetter[col].astype(int).describe()
# Out:
# count     48378.000000
# mean      47047.696308
# std       22473.219252
# min           0.000000
# 25%       32482.000000
# 50%       42644.000000
# 75%       57308.500000
# max      267734.000000
# Name: EARN_NE_MDN_3YR, dtype: float64

# %%
dfBetter[col].astype(int).median()
# Out:
# 42644.0

# %%
dfBetter.loc[dfBetter[col]=='32482']
# Out:
#           UNITID  OPEID6                                      INSTNM  \
# 36164   134130.0    1535                       University of Florida
# 56466   151661.0    7938  Lincoln College of Technology-Indianapolis
# 131427  203155.0    7598                             Hocking College
# 212675  484473.0    1535                University of Florida-Online
#
#                     CONTROL  MAIN  CIPCODE  \
# 36164                Public     1     2605
# 56466   Private, for-profit     1     4701
# 131427               Public     1      306
# 212675               Public     0     2605
#
#                                                   CIPDESC  CREDLEV  \
# 36164            Microbiological Sciences and Immunology.        3
# 56466   Electrical/Electronics Maintenance and Repair ...        2
# 131427     Wildlife and Wildlands Science and Management.        2
# 212675           Microbiological Sciences and Immunology.        3
#
# ...

# %%
dfBetter.loc[dfBetter[col]=='32482']

# %%
dfBetter.loc[dfBetter[col]=='42644']
# Out:
#           UNITID  OPEID6                             INSTNM  \
# 34155   132903.0    3954      University of Central Florida
# 131549  203368.0    3050            John Carroll University
# 187070  240277.0    3899  University of Wisconsin-Green Bay
#
#                    CONTROL  MAIN  CIPCODE  \
# 34155               Public     1     1311
# 131549  Private, nonprofit     1     1301
# 187070              Public     1     3027
#
#                                            CIPDESC  CREDLEV          CREDDESC  \
# 34155   Student Counseling and Personnel Services.        5   Master's Degree
# 131549                         Education, General.        3  Bachelors Degree
# 187070                              Human Biology.        3  Bachelors Degree
#
#         IPEDSCOUNT1  ...  EARN_COUNT_WNE_3YR EARN_CNTOVER150_3YR  \
# 34155          60.0  ...                  35                  29
# 131549         41.0  ...                  24                  24
# ...

# %%
dfBetter.loc[dfBetter[col]=='267734']
# Out:
#           UNITID  OPEID6                             INSTNM CONTROL  MAIN  \
# 134030  204796.0    3090  Ohio State University-Main Campus  Public     1
#
#         CIPCODE     CIPDESC  CREDLEV         CREDDESC  IPEDSCOUNT1  ...  \
# 134030     5104  Dentistry.        5  Master's Degree          NaN  ...
#
#         EARN_COUNT_WNE_3YR EARN_CNTOVER150_3YR EARN_COUNT_PELL_NE_3YR  \
# 134030                  26                  28      PrivacySuppressed
#
#        EARN_PELL_NE_MDN_3YR EARN_COUNT_NOPELL_NE_3YR EARN_NOPELL_NE_MDN_3YR  \
# 134030    PrivacySuppressed        PrivacySuppressed      PrivacySuppressed
#
#        EARN_COUNT_MALE_NE_3YR EARN_MALE_NE_MDN_3YR EARN_COUNT_NOMALE_NE_3YR  \
# 134030      PrivacySuppressed    PrivacySuppressed        PrivacySuppressed
#
#        EARN_NOMALE_NE_MDN_3YR
# 134030      PrivacySuppressed
#
# [1 rows x 121 columns]
